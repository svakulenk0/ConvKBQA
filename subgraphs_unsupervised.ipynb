# %%
# load subgraphs
import json

path = '/ivi/ilps/personal/svakule'
split = 'train_set'
conv_id = 1

qa_pairs = []
with open('%s/subgraphs/%s/%d.json' % (path, split, conv_id), "r") as data:
    conversation = json.load(data)
    seed_entity = conversation['seed_entity']
    print(conversation['seed_entity_text'])
    print(seed_entity)
    print('\n')
    
    for i, es in enumerate(conversation['answer_entities']):
        print(conversation['questions'][i])
        print(conversation['answer_texts'][i])
        for e in es:
            if e:
                print(e)
                qa_pairs.append([seed_entity, conversation['questions'][i], e])
    
    matched_entity_ids = [conversation['seed_entity_id']] + [a for _as in conversation['answer_ids'] for a in _as if a]
    print("\n%d matched entities" % len(matched_entity_ids))
    
    entity_ids = conversation['entities']
    predicate_ids = conversation['predicates']
    adjacencies = conversation['adjacencies']
    n_entities = len(entity_ids)
    print("Subgraph with %d entities and %d predicates" % (n_entities, len(predicate_ids)))
# Out:
# American Hustle
# http://www.wikidata.org/entity/Q9013673
#
#
# Does Bradley Cooper star in American Hustle?
# Yes
# When was he born?
# 5 January 1975
# And who composed?
# Danny Elfman
# http://www.wikidata.org/entity/Q193338
# Did the movie win a Golden Globe award?
# Yes
# How long is the movie?
# 138 minute
#
# 2 matched entities
# Subgraph with 1160 entities and 410 predicates

# %% [markdown]
# # Forward pass
#
# ## Check connectivity

# %%
# check the answer entity is reachable from the seed entity
import numpy as np
import scipy.sparse as sp

# load adjacencies
def generate_adj_sp(adjacencies, n_entities, include_inverse):
    '''
    Build adjacency matrix
    '''
    adj_shape = (n_entities, n_entities)
    
    # colect all predicate matrices separately into a list
    sp_adjacencies = []
    for edges in adjacencies:
        # split subject (row) and object (col) node URIs
        n_edges = len(edges)
        row, col = np.transpose(edges)
        
        # duplicate edges in the opposite direction
        if include_inverse:
            _row = np.hstack([row, col])
            col = np.hstack([col, row])
            row = _row
            n_edges *= 2
        
        # create adjacency matrix for this predicate
        data = np.ones(n_edges)
        adj = sp.csr_matrix((data, (row, col)), shape=adj_shape)
        sp_adjacencies.append(adj)
    
    return np.asarray(sp_adjacencies)

# seed activation
x = np.zeros(n_entities)
for e in matched_entity_ids:
    idx = entity_ids.index(e)
    x[idx] = 1

A = generate_adj_sp(adjacencies, n_entities, include_inverse=True)
for i, _A in enumerate(A):
    # MP
    _y = x @ _A
  
    # report edges between matched entities
    z = _y * x
    overlap = int(sum(z))
    if overlap:
        print("%d matched entities are connected with an edge" % int(overlap))
# Out:
# 2 matched entities are connected with an edge

# %% [markdown]
# ## Predict relations

# %%
# load all predicate labels
from predicates import properties

relationid2label = {}
for p in properties['results']['bindings']:
    _id = p['property']['value'].split('/')[-1]
    label = p['propertyLabel']['value']
    relationid2label[_id] = label
p_labels = list(relationid2label.values())
print(p_labels)
# Out:
# ['head of government', 'video', 'traffic sign', 'route map', 'highway system', 'country', 'image', 'place of birth', 'place of death', 'sex or gender', 'father', 'mother', 'spouse', 'country of citizenship', 'continent', 'instance of', 'head of state', 'capital', 'official language', 'currency', 'position held', 'child', 'flag image', 'shares border with', 'author', 'audio', 'family', 'member of sports team', 'director', 'screenwriter', 'constellation', 'discoverer or inventor', 'site of astronomical discovery', 'ancestral home', 'educated at', 'top-level Internet domain', 'connecting line', 'architect', 'anthem', 'composer', 'librettist', 'commissioned by', 'sexual orientation', 'main regulatory text', 'coat of arms image', 'noble title', 'editor', 'field of work', 'member of political party', 'native language', 'taxon rank', 'occupation', 'employer', 'signature', 'illustrator', 'measured physical quantity', 'founded by', 'airline hub', 'airline alliance', 'home venue', 'chemical structure', 'league', 'place of burial', 'item operated', 'basic form of government', 'publisher', 'maintained by', 'owned by', 'regulates (molecular biology)', 'physically interacts with', 'located in the administrative territorial entity', 'has dialect (DEPRECATED)', 'movement', 'genre', 'operator', 'named after', 'religion', 'IUCN conservation status', 'imported from Wikimedia project', 'based on', 'architectural style', 'contains administrative territorial entity', 'logo image', 'follows', 'followed by', 'killed by', 'seal image', 'headquarters location', 'cast member', 'producer', 'flag', 'award received', 'structure replaced by', 'chief executive officer', 'creator', 'parent taxon', 'ethnic group', 'performer', 'manufacturer', 'crosses', 'developer', 'part of the series', 'depicts', 'taxon range map image', 'endemic to', 'doctoral advisor', 'doctoral student', 'material used', 'location of discovery', 'twinned administrative body', 'main building contractor', 'legislative body', 'collection', 'minor planet group', 'adjacent station', 'business division', 'inflows', 'lake outflow', 'basin country', 'located in or next to body of water', 'bathymetry image', 'executive body', 'highest judicial authority', 'party chief representative', 'ISBN-13', 'International Standard Name Identifier', 'VIAF ID', 'spectral class', 'inventory number', 'ISO 639-1 code', 'ISO 639-2 code', 'ISO 639-3 code', 'ISO 639-6 code', 'galaxy morphological type', 'taxon name', 'GND ID', 'IATA airline designator', 'ICAO airline designator', 'CAS Registry Number', 'EC number', 'canonical SMILES', 'InChI', 'InChIKey', 'ISSN', 'coat of arms', 'IATA airport code', 'ICAO airport code', 'FAA airport code', 'military branch', 'locator map image', 'OCLC control number', 'Library of Congress authority ID', 'ULAN ID', 'element symbol', 'COSPAR ID', 'stated in', 'ticker symbol', 'official residence', 'record label', 'ATC code', 'Bibliothèque nationale de France ID', 'IdRef ID', 'CALIS ID', 'CiNii author ID (books)', 'production company', 'chemical formula', 'copyright license', 'location', 'programming language', 'GOST 7.75–97 code', 'subclass of', 'postal code', 'writing system', 'head coach', 'designed by', 'vessel class', 'place of publication', 'station code', 'ISO 3166-1 alpha-2 code', 'ISO 3166-1 alpha-3 code', 'ISO 3166-1 numeric code', 'ISO 3166-2 code', "category's main topic", 'EE breed number', 'page(s)', 'IETF language tag', 'operating system', 'director of photography', 'IMDb ID', 'Joconde work ID', 'software version identifier', 'National Diet Library ID', 'RKDimages ID', 'Entrez Gene ID', 'UniProt protein ID', 'HGNC gene symbol', 'HGNC ID', 'subsidiary', 'DOI', 'discography', 'Rijksmonument ID', 'is a list of', 'part of', 'original language of film or TV show', 'use', 'astronomic symbol image', 'Sandbox-CommonsMediaFile', 'Sandbox-Item', 'Sandbox-String', 'presenter', 'Commons category', 'INSEE municipality code', 'space launch vehicle', 'located on astronomical location',  ...

# %%
# P86 composer
print(qa_pairs)
p = qa_pairs[0][1]
print(p)
# Out:
# [['http://www.wikidata.org/entity/Q9013673', 'And who composed?', 'http://www.wikidata.org/entity/Q193338']]
# And who composed?

# %%
# encode all predicates
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('roberta-large-nli-stsb-mean-tokens')

sentence_embeddings = model.encode([p] + p_labels)

# %%
import scipy.spatial.distance

q_vector = sentence_embeddings[0]
dists = []
for i, p_vector in enumerate(sentence_embeddings[1:]):
    dists.append(scipy.spatial.distance.cosine(q_vector, p_vector))
assert len(dists) == len(p_labels)

# %%
k = 1
top_k = sorted(range(len(dists)), key=lambda k: dists[k])[:k]
for i in top_k:
    print(p_labels[i])
# Out:
# composer
