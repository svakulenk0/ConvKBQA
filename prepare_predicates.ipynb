# %%
# load graph
from hdt_utils import HDT_Graph
wikidata = HDT_Graph('wikidata2020')

# %%
# load all predicate labels
from predicates import properties

not_found = []
relationid2label = {}
for p in properties['results']['bindings']:
    label = p['propertyLabel']['value']
    key = p['property']['value'].split('/')[-1]
    _id = wikidata.look_up_id(key, 'predicate')
    if _id == 0:
        not_found.append(label)
    else:
        relationid2label[_id] = label

print("%d predicates found" % len(relationid2label))
print("%d predicates not found" % len(not_found))
# Out:
# 6995 predicates found
# 344 predicates not found

# %%
print(relationid2label)
# Out:
# {4906: 'head of government', 53: 'video', 431: 'traffic sign', 513: 'route map', 587: 'highway system', 681: 'country', 766: 'image', 859: 'place of birth', 956: 'place of death', 1058: 'sex or gender', 1159: 'father', 1453: 'mother', 1546: 'spouse', 1638: 'country of citizenship', 1924: 'continent', 2027: 'instance of', 2407: 'head of state', 2513: 'capital', 2615: 'official language', 2718: 'currency', 2818: 'position held', 2922: 'child', 3027: 'flag image', 3639: 'shares border with', 3948: 'author', 4051: 'audio', 4245: 'family', 4350: 'member of sports team', 4638: 'director', 4731: 'screenwriter', 4821: 'constellation', 5005: 'discoverer or inventor', 5416: 'site of astronomical discovery', 5519: 'ancestral home', 5821: 'educated at', 6718: 'top-level Internet domain', 6887: 'connecting line', 6917: 'architect', 6927: 'anthem', 6936: 'composer', 6946: 'librettist', 6955: 'commissioned by', 6976: 'sexual orientation', 6987: 'main regulatory text', 7005: 'coat of arms image', 7033: 'noble title', 7039: 'editor', 62: 'field of work', 72: 'member of political party', 82: 'native language', 102: 'taxon rank', 113: 'occupation', 132: 'employer', 142: 'signature', 150: 'illustrator', 159: 'measured physical quantity', 167: 'founded by', 177: 'airline hub', 184: 'airline alliance', 194: 'home venue', 212: 'chemical structure', 217: 'league', 227: 'place of burial', 245: 'item operated', 256: 'basic form of government', 262: 'publisher', 291: 'maintained by', 302: 'owned by', 313: 'regulates (molecular biology)', 324: 'physically interacts with', 343: 'located in the administrative territorial entity', 372: 'has dialect (DEPRECATED)', 383: 'movement', 393: 'genre', 403: 'operator', 412: 'named after', 432: 'religion', 442: 'IUCN conservation status', 461: 'imported from Wikimedia project', 471: 'based on', 512: 'architectural style', 514: 'contains administrative territorial entity', 525: 'logo image', 536: 'follows', 547: 'followed by', 557: 'killed by', 566: 'seal image', 577: 'headquarters location', 598: 'cast member', 609: 'producer', 619: 'flag', 644: 'award received', 655: 'structure replaced by', 671: 'chief executive officer', 682: 'creator', 692: 'parent taxon', 701: 'ethnic group', 725: 'performer', 732: 'manufacturer', 740: 'crosses', 749: 'developer', 757: 'part of the series', 767: 'depicts', 777: 'taxon range map image', 797: 'endemic to', 806: 'doctoral advisor', 817: 'doctoral student', 824: 'material used', 849: 'location of discovery', 860: 'twinned administrative body', 887: 'main building contractor', 898: 'legislative body', 907: 'collection', 918: 'minor planet group', 926: 'adjacent station', 945: 'business division', 957: 'inflows', 968: 'lake outflow', 1005: 'basin country', 1015: 'located in or next to body of water', 1026: 'bathymetry image', 1037: 'executive body', 1048: 'highest judicial authority', 1059: 'party chief representative', 1077: 'ISBN-13', 1086: 'International Standard Name Identifier', 1097: 'VIAF ID', 1108: 'spectral class', 1127: 'inventory number', 1137: 'ISO 639-1 code', 1148: 'ISO 639-2 code', 1160: 'ISO 639-3 code', 1171: 'ISO 639-6 code', 1190: 'galaxy morphological type', 1207: 'taxon name', 1224: 'GND ID', 1244: 'IATA airline designator', 1253: 'ICAO airline designator', 1258: 'CAS Registry Number', 1264: 'EC number', 1275: 'canonical SMILES', 1286: 'InChI', 1297: 'InChIKey', 1307: 'ISSN', 1318: 'coat of arms', 1329: 'IATA airport code', 1340: 'ICAO airport code', 1350: 'FAA airport code', 1361: 'military branch', 1371: 'locator map image', 1380: 'OCLC control number', 1390: 'Library of Congress authority ID', 1400: 'ULAN ID', 1411: 'element symbol', 1421: 'COSPAR ID', 1432: 'stated in', 1443: 'ticker symbol', 1572: 'official residence', 1583: 'record label', 1610: 'ATC code', 1620: 'Bibliothèque nationale de France ID', 1631: 'IdRef ID', 1639: 'CALIS ID', 1648: 'CiNii author ID (books)', 1655: 'production company', 1675: 'chemical formula', 1685: 'copyright license', 1695: 'lo ...
